# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
class RegLin:
    def __init__(self):
        self.pendiente=0
        self.intercepto=0
    def regresion_lineal(self,x,y):
        """calcula la pendiente y el intercepto de la regresion lineal"""
        n=len(x)
        detM=n*sum(x*x)-sum(x)*sum(x)
        detA=sum(y)*sum(x*x)-sum(x*y)*sum(x)
        detB=n*sum(x*y)-sum(x)*sum(y)
        a=detA/detM
        b=detB/detM
        self.pendiente=b
        self.intercepto=a
        return [a,b]
    def graficar(self,x,y):
        ycalc=x*self.pendiente+self.intercepto
        plt.plot(x,y,"ro")
        plt.plot(x,ycalc,"b--")
        plt.xlabel("t (seg)")
        plt.ylabel("distancia (m)")
        plt.title("distancia vs tiempo")
        plt.show()

# %%
def regresion_lineal(x,y):
    n=len(x)
    detM=n*sum(x*x)-sum(x)*sum(x)
    detA=sum(y)*sum(x*x)-sum(x*y)*sum(x)
    detB=n*sum(x*y)-sum(x)*sum(y)
    a=detA/detM
    b=detB/detM
    return [a,b]

# %%
x=np.array([0,1,2,3,4,5])
y=x*5+2+np.random.randn(6)*1
reg=regresion_lineal(x,y)
ycalc=x*reg[1]+reg[0]
ycalc
# Out:
# array([ 1.21731744,  6.39466971, 11.57202197, 16.74937424, 21.9267265 ,
#        27.10407876])

# %%
plt.plot(x,y,"ro")
plt.plot(x,ycalc,"b--")
plt.xlabel("t (seg)")
plt.ylabel("distancia (m)")
plt.title("distancia vs tiempo")
plt.show()

# %%
x=np.array([0,1,2,3,4,5])
y=x*5+4

reg=RegLin()
reg.regresion_lineal(x,y)
# Out:
# [4.0, 5.0]

# %%
reg.pendiente
# Out:
# 5.0

# %%
reg.intercepto
# Out:
# 4.0

# %%
x=np.array([0,1,2,3,4,5])
y=x*5+2+np.random.randn(6)*1

re=RegLin()
reg.regresion_lineal(x,y)
reg.graficar(x,y)
